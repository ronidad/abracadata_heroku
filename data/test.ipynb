# %%
dcc.Dropdown(
                  id = "dropdown_geoloc",
                  options= list_region, #The list has around 6/7 cities
                  value=['Zürich', 'Basel'], #Initial values,
                  multi=True)

@app.callback(
    Output(component_id='fig-map',component_property='figure'),
    [Input(component_id='dropdown_geoloc', component_property='value'])

def update_df(town):
	new_df = df1[(df1['region'].isin(town)]

# %%
import pandas as pd
df = pd.read_csv("combined_data.csv")
df['Total_deaths'] = df['Death_Illicit_drugs']+df['Death_Opioid']+df['Death_Alchohol']+df['Death_Other_drugs']+df['Death_Amphetamine']
df = df[['Entity','Year','Total_deaths']]
df.set_index('Year').T
# Out:
# Year                1990        1991        1992        1993        1994  \
# Entity           Algeria     Algeria     Algeria     Algeria     Algeria
# Total_deaths  497.837833  536.854425  581.654123  632.163825  698.486817
#
# Year                1995        1996        1997        1998        1999  ...  \
# Entity           Algeria     Algeria     Algeria     Algeria     Algeria  ...
# Total_deaths  756.958933  819.973237  888.046284  951.440835  1033.18849  ...
#
# Year                2008        2009        2010        2011        2012  \
# Entity          Zimbabwe    Zimbabwe    Zimbabwe    Zimbabwe    Zimbabwe
# Total_deaths  569.090844  563.134121  553.802156  537.262848  529.125092
#
# Year                2013        2014        2015        2016        2017
# Entity          Zimbabwe    Zimbabwe    Zimbabwe    Zimbabwe    Zimbabwe
# Total_deaths  529.949082  536.594654  554.170375  571.912561  588.055948
#
# [2 rows x 1512 columns]
